# %%
temp_path = '/content/drive/MyDrive/Best_Drummer_Ever.mp4'

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8s.pt', task='detect')
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 185MB/s]

# %%
results = model.predict(source=temp_path,
              save=True,
              stream=True,
              )

# %%
for r in results :
    temp = r.boxes
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# video 1/1 (frame 1187/6184) /content/drive/MyDrive/DataInsight_강의/2024_청주대학교/Best_Drummer_Ever.mp4: 384x640 12 persons, 2 backpacks, 3 handbags, 3 cups, 10.8ms
# video 1/1 (frame 1188/6184) /content/drive/MyDrive/DataInsight_강의/2024_청주대학교/Best_Drummer_Ever.mp4: 384x640 12 persons, 2 backpacks, 4 handbags, 3 cups, 10.9ms
# video 1/1 (frame 1189/6184) /content/drive/MyDrive/DataInsight_강의/2024_청주대학교/Best_Drummer_Ever.mp4: 384x640 12 persons, 2 backpacks, 4 handbags, 2 cups, 10.8ms
# video 1/1 (frame 1190/6184) /content/drive/MyDrive/DataInsight_강의/2024_청주대학교/Best_Drummer_Ever.mp4: 384x640 12 persons, 2 backpacks, 4 handbags, 1 cup, 10.8ms
# video 1/1 (frame 1191/6184) /content/drive/MyDrive/DataInsight_강의/2024_청주대학교/Best_Drummer_Ever.mp4: 384x640 13 persons, 2 backpacks, 2 handbags, 1 bottle, 1 cup, 10.8ms
# ...
