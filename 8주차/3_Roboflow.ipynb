# %% [markdown]
# ## Roboflow

# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="vOJCnFpStyQAaxJVYCrE")
project = rf.workspace("scott-harris-jzthv").project("football-analyzer")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# ...
# Extracting Dataset Version Zip to Football-Analyzer-1 in yolov8:: 100%|██████████| 43430/43430 [00:19<00:00, 2236.75it/s]

# %% [markdown]
# ## UltraLytics

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO, settings

# %%
settings
# Out:
# {'settings_version': '0.0.4',
#  'datasets_dir': '/content/datasets',
#  'weights_dir': 'weights',
#  'runs_dir': 'runs',
#  'uuid': '569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb',
#  'sync': True,
#  'api_key': '',
#  'openai_api_key': '',
#  'clearml': True,
#  'comet': True,
#  'dvc': True,
#  'hub': True,
#  'mlflow': True,
#  'neptune': True,
#  'raytune': True,
#  'tensorboard': True,
#  'wandb': True}

# %%
settings['datasets_dir'] = '/content/'

settings
# Out:
# {'settings_version': '0.0.4',
#  'datasets_dir': '/content/',
#  'weights_dir': 'weights',
#  'runs_dir': 'runs',
#  'uuid': '569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb',
#  'sync': True,
#  'api_key': '',
#  'openai_api_key': '',
#  'clearml': True,
#  'comet': True,
#  'dvc': True,
#  'hub': True,
#  'mlflow': True,
#  'neptune': True,
#  'raytune': True,
#  'tensorboard': True,
#  'wandb': True}

# %%
import yaml

# %%
with open('/content/Football-Analyzer-1/data.yaml', 'r+') as f:
    temp = yaml.load(f, Loader=yaml.FullLoader)
    temp['train'] = './train/images/'
    temp['val'] = './valid/images/'

with open('/content/Football-Analyzer-1/data.yaml', 'w') as f:
    yaml.dump(temp, f)

# %%
model = YOLO()
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 76.5MB/s]

# %%
model.train(model='/content/yolov8n.pt',
            data='/content/Football-Analyzer-1/data.yaml',
            epochs=20,
            patience=5
            )
# Out:
# Ultralytics YOLOv8.2.76 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...
